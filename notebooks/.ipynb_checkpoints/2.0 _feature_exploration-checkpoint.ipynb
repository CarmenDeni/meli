# %% [markdown]
# # Get features

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from data_experts.data_pipeline import DataPipeline
from data_experts.feature_engineer import FeatureEngineer
from data_experts.data_cleaner import DataCleaner

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
products =[
    "televisor%204k",
    "sistema%20de%20teatro%20en%20casa",
    "audifonos%20inalambricos",
    "consola%20de%20videojuegos",
    "smartphone%20android",
    "laptop%20gaming",
    "tablet%20android",
    "bocina%20bluetooth",
    "smart%20tv",
    "barra%20de%20sonido%20dolby%20atmos",
    "audifonos%20gaming",
    "reloj%20inteligente",
    "monitor%20curvo",
    "disco%20duro%20externo",
    "auriculares%20inalambricos",
    "gafas%20de%20realidad%20virtual",
    "teclado%20gaming",
    "mouse%20inalambrico",
    "dispositivo%20inteligente%20para%20el%20hogar",
    "adaptador%20bluetooth",
    "silla%20gamer",
    "pc%20de%20escritorio",
    "proyector%20para%20cine%20en%20casa",
    "focos%20inteligentes",
    "robot%20aspiradora",
    "camara%20reflex",
    "camara%20sin%20espejo",
    "monitor%20gaming",
    "cargador%20portatil",
    "tarjeta%20grafica",
    "router%20wifi",
    "audifonos%20con%20cancelacion%20de%20ruido",
    "cargador%20inalambrico",
    "ssd%20portatil",
    "refrigerador%20inteligente",
    "patineta%20electrica",
    "pulsera%20fitness",
    "timbre%20inteligente",
    "camara%20de%20seguridad%20para%20el%20hogar",
    "funda%20para%20tablet"
]

access_token = 'TU_ACCESS_TOKEN'

cleaner = DataPipeline(products, access_token)
df_cleaned = cleaner.process_data()

engineer = FeatureEngineer(products, access_token)
engineer.dataframe = df_cleaned

# %%
df0 = engineer.apply_all_features()

# %%
df0.columns
# Out:
# Index(['id', 'title', 'condition', 'thumbnail_id', 'catalog_product_id',
#        'listing_type_id', 'sanitized_title', 'permalink', 'buying_mode',
#        'site_id', 'category_id', 'domain_id', 'thumbnail', 'currency_id',
#        'order_backend', 'price', 'original_price', 'sale_price',
#        'available_quantity', 'official_store_id', 'use_thumbnail_id',
#        'accepts_mercadopago', 'shipping', 'stop_time', 'seller', 'attributes',
#        'installments', 'winner_item_id', 'catalog_listing', 'discounts',
#        'promotions', 'differential_pricing', 'inventory_id',
#        'official_store_name', 'query', 'variation_filters', 'variations_data',
#        'variation_id', 'brand', 'discount', 'days_until_discount_end',
#        'data_timestamp', 'free_shipping', 'store_pick_up', 'is_official_store',
#        'installment_quantity', 'installment_rate', 'has_msi', 'msi'],
#       dtype='object')

# %%
df0.drop_duplicates(subset = ["catalog_product_id", "official_store_id"], inplace = True)

# %%
df0["catalog_product_id"].nunique()
# Out:
# 1293

# %%
df0.shape
# Out:
# (1343, 49)

# %%
df0["query"]
# Out:
# 0              tv
# 1              tv
# 2              tv
# 3              tv
# 4              tv
# 5              tv
# 6              tv
# 7              tv
# 8              tv
# 9              tv
# 10             tv
# 11             tv
# 12             tv
# 13             tv
# 14             tv
# 15             tv
# 16             tv
# 17             tv
# 18             tv
# 19             tv
# 20             tv
# 21             tv
# 22             tv
# 23             tv
# 24             tv
# 25             tv
# 26             tv
# 27             tv
# 28             tv
# 29             tv
# 30             tv
# 31             tv
# 32             tv
# 33             tv
# 34             tv
# 35             tv
# 36             tv
# 37             tv
# 38             tv
# 39             tv
# 40             tv
# 41             tv
# 42             tv
# 43             tv
# 44             tv
# 45             tv
# 46             tv
# 47             tv
# 48             tv
# 49             tv
# 50       pantalla
# 51       pantalla
# 52       pantalla
# 53       pantalla
# 54       pantalla
# 55       pantalla
# 56       pantalla
# 57       pantalla
# 58       pantalla
# 59       pantalla
# 60       pantalla
# 61       pantalla
# 62       pantalla
# 63       pantalla
# 64       pantalla
# 65       pantalla
# 66       pantalla
# 67       pantalla
# 68       pantalla
# 69       pantalla
# 70       pantalla
# 71       pantalla
# 72       pantalla
# 73       pantalla
# 74       pantalla
# 75       pantalla
# 76       pantalla
# 77       pantalla
# 78       pantalla
# 79       pantalla
# 80       pantalla
# 81       pantalla
# 82       pantalla
# 83       pantalla
# 84       pantalla
# 85       pantalla
# 86       pantalla
# 87       pantalla
# 88       pantalla
# 89       pantalla
# 90       pantalla
# 91       pantalla
# 92       pantalla
# 93       pantalla
# 94       pantalla
# 95       pantalla
# 96       pantalla
# 97       pantalla
# 98       pantalla
# 99       pantalla
# 100          tele
# 101          tele
# 102          tele
# 103          tele
# 104          tele
# 105          tele
# 106          tele
# 107          tele
# 108          tele
# 109          tele
# 110          tele
# 111          tele
# 112          tele
# 113          tele
# 114          tele
# 115    television
# 116    television
# 117    television
# 118    television
# 119    television
# 120    television
# 121    television
# 122    television
# 123    television
# 124    television
# 125    television
# 126    television
# 127    television
# 128    television
# 129    television
# 130    television
# 131    television
# 132    television
# 133    television
# 134    television
# 135    television
# 136    television
# 137    television
# 138    television
# 139    television
# 140    television
# 141    television
# 142    television
# 143    television
# 144    television
# 145    television
# 146    television
# 147    television
# 148    television
# 149    television
# 150    television
# 151    television
# 152    television
# 153    television
# 154    television
# 155    television
# 156    television
# 157    television
# 158    television
# 159    television
# 160    television
# 161    television
# 162    television
# 163    television
# 164    television
# Name: query, dtype: object

# %%
features_to_analize = ["discount", "buying_mode", "query",
                       'installment_quantity', 'installment_rate', 'has_msi', 'msi',
                       "days_until_discount_end", "condition",
                       "brand", "free_shipping", 'store_pick_up',
                       "domain_id", ""
                       'is_official_store', "listing_type_id"]

df = df0[features_to_analize]

# %% [markdown]
# # df general info and structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   discount                 49 non-null     float64
#  1   buying_mode              49 non-null     object
#  2   installment_quantity     49 non-null     int64
#  3   installment_rate         49 non-null     float64
#  4   has_msi                  49 non-null     bool
#  5   msi                      49 non-null     int64
#  6   days_until_discount_end  49 non-null     int64
#  7   condition                49 non-null     object
#  8   brand                    49 non-null     object
#  9   free_shipping            49 non-null     bool
#  10  store_pick_up            49 non-null     bool
#  11  domain_id                49 non-null     object
#  12  is_official_store        49 non-null     bool
#  13  listing_type_id          49 non-null     object
# dtypes: bool(4), float64(2), int64(3), object(5)
# memory usage: 4.1+ KB

# %%
df.describe(include='all')
# Out:
#          discount buying_mode  installment_quantity  installment_rate has_msi  \
# count   49.000000          49             49.000000         49.000000      49
# unique        NaN           1                   NaN               NaN       2
# top           NaN  buy_it_now                   NaN               NaN   False
# freq          NaN          49                   NaN               NaN      39
# mean    16.350698         NaN              5.367347         20.711020     NaN
# std     13.477519         NaN              2.017567         17.027006     NaN
# min      0.000000         NaN              1.000000          0.000000     NaN
# 25%      7.122767         NaN              6.000000          0.000000     NaN
# 50%     15.000178         NaN              6.000000         12.950000     NaN
# 75%     22.000000         NaN              6.000000         37.930000     NaN
# max     46.999992         NaN             12.000000         37.930000     NaN
#
#               msi  days_until_discount_end condition           brand  \
# count   49.000000                49.000000        49              49
# unique        NaN                      NaN         1              24
# top           NaN                      NaN       new  Tienda Objetos
# freq          NaN                      NaN        49              13
# mean     1.897959                 6.673469       NaN             NaN
# std      2.238349                11.594517       NaN             NaN
# min      1.000000                 0.000000       NaN             NaN
# 25%      1.000000                 0.000000       NaN             NaN
# 50%      1.000000                 0.000000       NaN             NaN
# 75%      1.000000                 2.000000       NaN             NaN
# max     12.000000                30.000000       NaN             NaN
#
#        free_shipping store_pick_up                    domain_id  \
# count             49            49                           49
# unique             2             1                           19
# top             True         False  MLA-WALL_AND_CEILING_LIGHTS
# freq              25            49                           13
# mean             NaN           NaN                          NaN
# std              NaN           NaN                          NaN
# min              NaN           NaN                          NaN
# 25%              NaN           NaN                          NaN
# 50%              NaN           NaN                          NaN
# 75%              NaN           NaN                          NaN
# max              NaN           NaN                          NaN
#
#        is_official_store listing_type_id
# count                 49              49
# unique                 2               2
# top                 True    gold_special
# freq                  32              39
# mean                 NaN             NaN
# std                  NaN             NaN
# min                  NaN             NaN
# 25%                  NaN             NaN
# 50%                  NaN             NaN
# 75%                  NaN             NaN
# max                  NaN             NaN

# %%
df.isnull().sum()
# Out:
# discount                   0
# buying_mode                0
# installment_quantity       0
# installment_rate           0
# has_msi                    0
# msi                        0
# days_until_discount_end    0
# condition                  0
# brand                      0
# free_shipping              0
# store_pick_up              0
# domain_id                  0
# is_official_store          0
# listing_type_id            0
# dtype: int64

# %% [markdown]
# # Features vs target

# %%
import seaborn as sns
sns.pairplot(df)
# Out:
# /Users/deni/anaconda3/envs/xochitl2/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Group by features

# %%
from data_experts.analyst import Analyst

# %%
analyst = Analyst([product], access_token)
analyst.dataframe = df

# %%
df.head()
# Out:
#     discount buying_mode  installment_quantity has_msi  \
# 0  22.000000  buy_it_now                   6.0   False
# 1  15.112231  buy_it_now                   6.0   False
# 2  23.689735  buy_it_now                   6.0   False
# 3   5.000000  buy_it_now                   6.0    True
# 4        NaN  buy_it_now                  12.0    True
#
#    days_until_discount_end      brand  free_shipping  store_pick_up  \
# 0                      2.0  Hub Store           True          False
# 1                      1.0   Logitech          False          False
# 2                      0.0    Candela          False          False
# 3                     30.0      Yelmo           True          False
# 4                      NaN   Redragon           True          False
#
#    is_official_store listing_type_id
# 0              False    gold_special
# 1              False    gold_special
# 2               True    gold_special
# 3               True        gold_pro
# 4              False        gold_pro

# %%
df.columns
# Out:
# Index(['discount', 'buying_mode', 'installment_quantity', 'has_msi',
#        'days_until_discount_end', 'brand', 'free_shipping', 'store_pick_up',
#        'is_official_store', 'listing_type_id'],
#       dtype='object')

# %%
result = analyst.analyze_by_features(['brand', "days_until_discount_end"]).unstack()
result
# Out:
#                           discount                                   \
# days_until_discount_end         0          1          2          17
# brand
# AKG                       0.000000        NaN        NaN        NaN
# BAW                            NaN        NaN  11.000000        NaN
# Candela                  23.689735        NaN        NaN        NaN
# Candil                   16.838583        NaN        NaN        NaN
# Citiblancoh               7.122767        NaN        NaN        NaN
# Electroland                    NaN  43.000000        NaN        NaN
# Framingham Pharma              NaN        NaN  40.000000        NaN
# GA.MA Italy                    NaN        NaN  40.000000        NaN
# Handa                          NaN        NaN  29.067696        NaN
# Hub Store                      NaN        NaN  22.000000        NaN
# K78                            NaN        NaN  40.000000        NaN
# K9 Dog Trainers           0.000000        NaN        NaN        NaN
# Keber                          NaN        NaN  10.000000        NaN
# Logitech                  0.000000  15.112231        NaN        NaN
# Lüsqtoff                  0.000000        NaN        NaN        NaN
# Macroled                 19.871363        NaN        NaN        NaN
# Mattel                         NaN        NaN        NaN  44.019564
# Melisam                        NaN        NaN        NaN        NaN
# Peabody                   9.091074        NaN        NaN        NaN
# Redragon                  4.875044        NaN        NaN        NaN
# SanDisk                   0.000000        NaN        NaN        NaN
# Tienda Objetos           18.961528        NaN        NaN        NaN
# XLS                       0.000000        NaN        NaN        NaN
# Yelmo                          NaN        NaN        NaN        NaN
#
#
# days_until_discount_end         28         30
# brand
# AKG                            NaN        NaN
# BAW                            NaN        NaN
# Candela                        NaN        NaN
# Candil                         NaN  12.000549
# Citiblancoh                    NaN        NaN
# Electroland                    NaN        NaN
# Framingham Pharma              NaN        NaN
# GA.MA Italy                    NaN        NaN
# Handa                          NaN        NaN
# Hub Store                      NaN        NaN
# K78                            NaN        NaN
# K9 Dog Trainers                NaN        NaN
# Keber                          NaN        NaN
# Logitech                       NaN        NaN
# Lüsqtoff                       NaN        NaN
# Macroled                 15.000000  14.995158
# Mattel                         NaN        NaN
# Melisam                        NaN  46.999992
# Peabody                        NaN        NaN
# Redragon                       NaN        NaN
# SanDisk                        NaN        NaN
# Tienda Objetos           14.998825        NaN
# XLS                            NaN        NaN
# Yelmo                          NaN   5.000000

# %%
sns.heatmap(result)
# Out:
# <Axes: xlabel='None-days_until_discount_end', ylabel='brand'>

# %%
df.columns
# Out:
# Index(['discount', 'buying_mode', 'installment_quantity', 'installment_rate',
#        'has_msi', 'msi', 'days_until_discount_end', 'condition', 'brand',
#        'free_shipping', 'store_pick_up', 'domain_id', 'is_official_store',
#        'listing_type_id'],
#       dtype='object')

# %%
result = analyst.analyze_by_features(['domain_id', "days_until_discount_end"]).unstack()
result
# Out:
#                                         discount                        \
# days_until_discount_end                       0          1          2
# domain_id
# MLA-AIR_COMPRESSORS                     0.000000        NaN        NaN
# MLA-AIR_CONDITIONER_REMOTE_CONTROLS          NaN  43.000000        NaN
# MLA-CIRCUIT_BREAKERS                         NaN        NaN  11.000000
# MLA-DATA_CABLES_AND_ADAPTERS                 NaN        NaN  26.711797
# MLA-DIECAST_VEHICLES                         NaN        NaN        NaN
# MLA-ELECTRIC_JUGS                       9.091074        NaN        NaN
# MLA-HAIR_STRAIGHTENERS                       NaN        NaN  40.000000
# MLA-HEADPHONES                          0.000000        NaN        NaN
# MLA-KITCHEN_TORCHES                          NaN        NaN  10.000000
# MLA-LIGHT_BULBS                        18.354229        NaN  11.000000
# MLA-MANUAL_INDOOR_CURTAINS_AND_BLINDS   7.122767        NaN        NaN
# MLA-MEMORY_CARDS                        0.000000        NaN        NaN
# MLA-PC_KEYBOARDS                        3.250030  15.112231        NaN
# MLA-PET_HARNESSES                       0.000000        NaN        NaN
# MLA-SUPPLEMENTS                              NaN        NaN  40.000000
# MLA-TIRE_SNOW_CHAINS                         NaN        NaN  40.000000
# MLA-VEHICLE_EMERGENCY_KITS                   NaN        NaN        NaN
# MLA-VEHICLE_LED_BULBS                   0.000000        NaN        NaN
# MLA-WALL_AND_CEILING_LIGHTS            19.818293        NaN        NaN
#
#
# days_until_discount_end                       17         28         30
# domain_id
# MLA-AIR_COMPRESSORS                          NaN        NaN        NaN
# MLA-AIR_CONDITIONER_REMOTE_CONTROLS          NaN        NaN        NaN
# MLA-CIRCUIT_BREAKERS                         NaN        NaN        NaN
# MLA-DATA_CABLES_AND_ADAPTERS                 NaN        NaN        NaN
# MLA-DIECAST_VEHICLES                   44.019564        NaN        NaN
# MLA-ELECTRIC_JUGS                            NaN        NaN   5.000000
# MLA-HAIR_STRAIGHTENERS                       NaN        NaN        NaN
# MLA-HEADPHONES                               NaN        NaN        NaN
# MLA-KITCHEN_TORCHES                          NaN        NaN        NaN
# MLA-LIGHT_BULBS                              NaN  15.000000  13.497854
# MLA-MANUAL_INDOOR_CURTAINS_AND_BLINDS        NaN        NaN        NaN
# MLA-MEMORY_CARDS                             NaN        NaN        NaN
# MLA-PC_KEYBOARDS                             NaN        NaN        NaN
# MLA-PET_HARNESSES                            NaN        NaN        NaN
# MLA-SUPPLEMENTS                              NaN        NaN        NaN
# MLA-TIRE_SNOW_CHAINS                         NaN        NaN        NaN
# MLA-VEHICLE_EMERGENCY_KITS                   NaN        NaN  46.999992
# MLA-VEHICLE_LED_BULBS                        NaN        NaN        NaN
# MLA-WALL_AND_CEILING_LIGHTS                  NaN  14.998825        NaN

# %% [markdown]
# # Bodega

# %% [markdown]
# ## Agregar esta lógica a los tests

# %%
#agregar a tests
df0[["discount", "days_until_discount_end"]]

# %%
#esto se debe poner en los tests
df0[["installments", "has_msi", "installment_rate", "installment_quantity"]]
# Out:
#                                          installments  has_msi  \
# 0   {'quantity': 6, 'amount': 7977.46, 'rate': 37....    False
# 1   {'quantity': 6, 'amount': 2634.23, 'rate': 37....    False
# 2   {'quantity': 6, 'amount': 1116.77, 'rate': 12....    False
# 3   {'quantity': 6, 'amount': 9499.84, 'rate': 0, ...     True
# 4   {'quantity': 12, 'amount': 6628.25, 'rate': 0,...     True
# 5   {'quantity': 6, 'amount': 11493.94, 'rate': 37...    False
# 6   {'quantity': 6, 'amount': 2267.49, 'rate': 12....    False
# 7   {'quantity': 6, 'amount': 22821.44, 'rate': 37...    False
# 8   {'quantity': 6, 'amount': 2068.06, 'rate': 12....    False
# 9   {'quantity': 6, 'amount': 7724.08, 'rate': 37....    False
# 10  {'quantity': 9, 'amount': 40933.22, 'rate': 0,...     True
# 11  {'quantity': 6, 'amount': 6394.21, 'rate': 37....    False
# 12  {'quantity': 6, 'amount': 2315.16, 'rate': 12....    False
# 13  {'quantity': 6, 'amount': 3300.42, 'rate': 12....    False
# 14  {'quantity': 3, 'amount': 12768, 'rate': 0, 'c...     True
# 15  {'quantity': 6, 'amount': 14751.38, 'rate': 37...    False
# 16  {'quantity': 6, 'amount': 5285.02, 'rate': 37....    False
# 17  {'quantity': 6, 'amount': 3446.67, 'rate': 12....    False
# 18  {'quantity': 6, 'amount': 5285.02, 'rate': 37....    False
# 19  {'quantity': 6, 'amount': 8772.35, 'rate': 37....    False
# 20  {'quantity': 3, 'amount': 40390.49, 'rate': 0,...     True
# 21  {'quantity': 6, 'amount': 8881.77, 'rate': 37....    False
# 22                                               None    False
# 23  {'quantity': 3, 'amount': 18693.18, 'rate': 0,...     True
# 24  {'quantity': 3, 'amount': 28697.48, 'rate': 0,...     True
# 25  {'quantity': 6, 'amount': 2091.78, 'rate': 37....    False
# 26  {'quantity': 6, 'amount': 3379.28, 'rate': 37....    False
# 27  {'quantity': 6, 'amount': 6513.97, 'rate': 37....    False
# 28  {'quantity': 6, 'amount': 7605.05, 'rate': 37....    False
# 29  {'quantity': 6, 'amount': 5689.47, 'rate': 37....    False
# 30                                               None    False
# 31  {'quantity': 6, 'amount': 6666.39, 'rate': 37....    False
# 32  {'quantity': 6, 'amount': 1321.47, 'rate': 37....    False
# 33                                               None    False
# 34  {'quantity': 6, 'amount': 1156.8, 'rate': 12.9...    False
# 35  {'quantity': 6, 'amount': 18933.17, 'rate': 0,...     True
# 36  {'quantity': 6, 'amount': 7408.5, 'rate': 37.9...    False
# 37  {'quantity': 6, 'amount': 9666.67, 'rate': 0, ...     True
# 38  {'quantity': 6, 'amount': 1206.49, 'rate': 12....    False
# 39                                               None    False
# 40  {'quantity': 6, 'amount': 6119.64, 'rate': 37....    False
# 41  {'quantity': 6, 'amount': 1687.3, 'rate': 37.9...    False
# 42                                               None    False
# 43  {'quantity': 6, 'amount': 6341.25, 'rate': 37....    False
# 44  {'quantity': 6, 'amount': 2894.23, 'rate': 37....    False
# 45  {'quantity': 6, 'amount': 986.6, 'rate': 12.95...    False
# 46  {'quantity': 6, 'amount': 1116.77, 'rate': 12....    False
# 47  {'quantity': 3, 'amount': 15919.33, 'rate': 0,...     True
# 48  {'quantity': 6, 'amount': 2444.99, 'rate': 12....    False
#
#     installment_rate  installment_quantity
# 0              37.93                     6
# 1              37.93                     6
# 2              12.95                     6
# 3               0.00                     6
# 4               0.00                    12
# 5              37.93                     6
# 6              12.95                     6
# 7              37.93                     6
# 8              12.95                     6
# 9              37.93                     6
# 10              0.00                     9
# 11             37.93                     6
# 12             12.95                     6
# 13             12.95                     6
# 14              0.00                     3
# 15             37.93                     6
# 16             37.93                     6
# 17             12.95                     6
# 18             37.93                     6
# 19             37.93                     6
# 20              0.00                     3
# 21             37.93                     6
# 22              0.00                     1
# 23              0.00                     3
# 24              0.00                     3
# 25             37.93                     6
# 26             37.93                     6
# 27             37.93                     6
# 28             37.93                     6
# 29             37.93                     6
# 30              0.00                     1
# 31             37.93                     6
# 32             37.93                     6
# 33              0.00                     1
# 34             12.95                     6
# 35              0.00                     6
# 36             37.93                     6
# 37              0.00                     6
# 38             12.95                     6
# 39              0.00                     1
# 40             37.93                     6
# 41             37.93                     6
# 42              0.00                     1
# 43             37.93                     6
# 44             37.93                     6
# 45             12.95                     6
# 46             12.95                     6
# 47              0.00                     3
# 48             12.95                     6
